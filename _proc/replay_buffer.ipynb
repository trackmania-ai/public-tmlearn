# %% [raw]
# ---
# description: Buffer that save past experience and allow to sample.
# output-file: replay_buffer.html
# title: Replay Buffer
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(PrioritizedReplayBuffer)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/replay_buffer.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### PrioritizedReplayBuffer
#
# >      PrioritizedReplayBuffer (capacity, queue_capacity=128, prob_alpha=0.5,
# >                               e=1e-05, beta=1.0, beta_increment=1e-05,
# >                               device='cpu')
#
# Initialize self.  See help(type(self)) for accurate signature.
