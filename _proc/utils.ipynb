# %% [raw]
# ---
# description: Various utilities for trackmania-ai project
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(log_memory)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/utils.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### log_memory
#
# >      log_memory (suffix='')

# %%
#| echo: false
#| output: asis
show_doc(format_duration)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/utils.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### format_duration
#
# >      format_duration (seconds)

# %%
#| echo: false
#| output: asis
show_doc(format_date)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/utils.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### format_date
#
# >      format_date (f='%Y/%m/%d %H:%M')

# %%
#| echo: false
#| output: asis
show_doc(IntervalCall)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/utils.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### IntervalCall
#
# >      IntervalCall (fn, interval)
#
# A class that represents a thread of control.
#
# This class can be safely subclassed in a limited fashion. There are two ways
# to specify the activity: by passing a callable object to the constructor, or
# by overriding the run() method in a subclass.

# %%
#| echo: false
#| output: asis
show_doc(Counter)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/utils.py#L51){target="_blank" style="float:right; font-size:smaller"}
#
# ### Counter
#
# >      Counter (value=0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Timer)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/utils.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### Timer
#
# >      Timer (timeout)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Triggers)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/utils.py#L80){target="_blank" style="float:right; font-size:smaller"}
#
# ### Triggers
#
# >      Triggers (trigger_values, condition=<function <lambda>>)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(attrsToDict)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/utils.py#L106){target="_blank" style="float:right; font-size:smaller"}
#
# ### attrsToDict
#
# >      attrsToDict (obj, attrs)
