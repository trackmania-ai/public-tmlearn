# %% [raw]
# ---
# description: Agent allowing to pick an action and fit one batch for training using
#   DQN algorithm
# output-file: agent_dqn.html
# title: DQN Agent
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(NoExploration)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/agent/dqn.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### NoExploration
#
# >      NoExploration ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(RankSoftmaxExploration)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/agent/dqn.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### RankSoftmaxExploration
#
# >      RankSoftmaxExploration (tau=1.0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ResmaxExploration)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/agent/dqn.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### ResmaxExploration
#
# >      ResmaxExploration (eta)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(EpsilonGreedyExploration)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/agent/dqn.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### EpsilonGreedyExploration
#
# >      EpsilonGreedyExploration (epsilon=0.1)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Exploration)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/agent/dqn.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### Exploration
#
# >      Exploration ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(DqnAgent)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/agent/dqn.py#L80){target="_blank" style="float:right; font-size:smaller"}
#
# ### DqnAgent
#
# >      DqnAgent (model, exploration=<__main__.EpsilonGreedyExploration object at
# >                0x7fd07496dea0>, device='cpu', gamma=0.99,
# >                update_target_every=320,
# >                optimizer_fn=functools.partial(<function Adam at
# >                0x7fd074b2b9a0>, lr=1e-05, wd=1e-05), loss_fn=SmoothL1Loss())
#
# Initialize self.  See help(type(self)) for accurate signature.
