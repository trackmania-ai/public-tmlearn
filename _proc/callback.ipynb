# %% [raw]
# ---
# description: Callbacks used by Learner and Collector to modify their behaviour
# output-file: callback.html
# title: Callback
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Callback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/callback.py#L53){target="_blank" style="float:right; font-size:smaller"}
#
# ### Callback
#
# >      Callback ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Callbackable)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/callback.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### Callbackable
#
# >      Callbackable (cbs=None)
#
# Initialize self.  See help(type(self)) for accurate signature.
