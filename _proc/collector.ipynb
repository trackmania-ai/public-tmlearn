# %% [raw]
# ---
# description: Collect experiences and put them to a replay buffer
# output-file: collector.html
# title: Collector
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(SessionCollector)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L72){target="_blank" style="float:right; font-size:smaller"}
#
# ### SessionCollector
#
# >      SessionCollector (map_uid, cbs, env, agent, replay_buffer,
# >                        session_scheduler)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(CollectorWorker)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L38){target="_blank" style="float:right; font-size:smaller"}
#
# ### CollectorWorker
#
# >      CollectorWorker (env, cbs, agent, replay_buffer, session_scheduler,
# >                       next_map_queue, done_map_queue)
#
# Process objects represent activity that is run in a separate process
#
# The class is analogous to `threading.Thread`

# %% [markdown]
# # Session scheduler

# %%
#| echo: false
#| output: asis
show_doc(SessionScheduler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L147){target="_blank" style="float:right; font-size:smaller"}
#
# ### SessionScheduler
#
# >      SessionScheduler (nb_episode)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Exceptions

# %%
#| echo: false
#| output: asis
show_doc(CancelPushException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L187){target="_blank" style="float:right; font-size:smaller"}
#
# ### CancelPushException
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(RecoverEnvException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L183){target="_blank" style="float:right; font-size:smaller"}
#
# ### RecoverEnvException
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(CancelEpisodeException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L179){target="_blank" style="float:right; font-size:smaller"}
#
# ### CancelEpisodeException
#
#
#
# Common base class for all non-exit exceptions.

# %% [markdown]
# ## Callbacks

# %%
#| echo: false
#| output: asis
show_doc(WandbGhostSaver)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L276){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbGhostSaver
#
# >      WandbGhostSaver (run, dir_size=1000)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(WandbCollectorCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L191){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbCollectorCallback
#
# >      WandbCollectorCallback (project, entity, group,
# >                              save_memory_summary=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ExplorationSwitcherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L309){target="_blank" style="float:right; font-size:smaller"}
#
# ### ExplorationSwitcherCallback
#
# >      ExplorationSwitcherCallback (explorations)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(IgnoreFinished)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L378){target="_blank" style="float:right; font-size:smaller"}
#
# ### IgnoreFinished
#
# >      IgnoreFinished ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(IgnoreRespawnAndUnfinished)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L370){target="_blank" style="float:right; font-size:smaller"}
#
# ### IgnoreRespawnAndUnfinished
#
# >      IgnoreRespawnAndUnfinished ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(IgnoreLaggyStepCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L361){target="_blank" style="float:right; font-size:smaller"}
#
# ### IgnoreLaggyStepCallback
#
# >      IgnoreLaggyStepCallback (timeout=0.1)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(MemoryFullRecoverCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L349){target="_blank" style="float:right; font-size:smaller"}
#
# ### MemoryFullRecoverCallback
#
# >      MemoryFullRecoverCallback (percent_threshold=90.0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(TelemetryTimeoutRecoverCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L337){target="_blank" style="float:right; font-size:smaller"}
#
# ### TelemetryTimeoutRecoverCallback
#
# >      TelemetryTimeoutRecoverCallback (timeout=10.0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(LagCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L384){target="_blank" style="float:right; font-size:smaller"}
#
# ### LagCallback
#
# >      LagCallback ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(SessionPublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L509){target="_blank" style="float:right; font-size:smaller"}
#
# ### SessionPublisherCallback
#
# >      SessionPublisherCallback (publisher_queue)
#
# Require WandbCollectorCallback

# %%
#| echo: false
#| output: asis
show_doc(SessionStats)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L443){target="_blank" style="float:right; font-size:smaller"}
#
# ### SessionStats

# %%
#| echo: false
#| output: asis
show_doc(StepPublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L434){target="_blank" style="float:right; font-size:smaller"}
#
# ### StepPublisherCallback
#
# >      StepPublisherCallback (publisher_queue)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ActionPublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L420){target="_blank" style="float:right; font-size:smaller"}
#
# ### ActionPublisherCallback
#
# >      ActionPublisherCallback (publisher_queue)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(PublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L409){target="_blank" style="float:right; font-size:smaller"}
#
# ### PublisherCallback
#
# >      PublisherCallback (publisher_queue)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(publish)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L402){target="_blank" style="float:right; font-size:smaller"}
#
# ### publish
#
# >      publish (queue, payload)
