# %% [raw]
# ---
# description: Collect experiences and put them to a replay buffer
# output-file: collector.html
# title: Collector
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(SessionCollector)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L72){target="_blank" style="float:right; font-size:smaller"}
#
# ### SessionCollector
#
# >      SessionCollector (cbs, env, agent, replay_buffer, session_scheduler)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(CollectorWorker)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### CollectorWorker
#
# >      CollectorWorker (env, cbs, agent, replay_buffer, session_scheduler,
# >                       next_map_queue, done_map_queue)
#
# Process objects represent activity that is run in a separate process
#
# The class is analogous to `threading.Thread`

# %% [markdown]
# # Session scheduler

# %%
#| echo: false
#| output: asis
show_doc(SessionScheduler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L153){target="_blank" style="float:right; font-size:smaller"}
#
# ### SessionScheduler
#
# >      SessionScheduler (nb_episode)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Exceptions

# %%
#| echo: false
#| output: asis
show_doc(CancelPushException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L193){target="_blank" style="float:right; font-size:smaller"}
#
# ### CancelPushException
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(RecoverEnvException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L189){target="_blank" style="float:right; font-size:smaller"}
#
# ### RecoverEnvException
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(CancelEpisodeException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L185){target="_blank" style="float:right; font-size:smaller"}
#
# ### CancelEpisodeException
#
#
#
# Common base class for all non-exit exceptions.

# %% [markdown]
# ## Callbacks

# %%
#| echo: false
#| output: asis
show_doc(WandbGhostSaver)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L267){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbGhostSaver
#
# >      WandbGhostSaver (run, dir_size=1000)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(WandbCollectorCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L197){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbCollectorCallback
#
# >      WandbCollectorCallback (project, entity, group)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ExplorationSwitcherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L300){target="_blank" style="float:right; font-size:smaller"}
#
# ### ExplorationSwitcherCallback
#
# >      ExplorationSwitcherCallback (explorations)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(IgnoreFinished)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L369){target="_blank" style="float:right; font-size:smaller"}
#
# ### IgnoreFinished
#
# >      IgnoreFinished ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(IgnoreRespawnAndUnfinished)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L361){target="_blank" style="float:right; font-size:smaller"}
#
# ### IgnoreRespawnAndUnfinished
#
# >      IgnoreRespawnAndUnfinished ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(IgnoreLaggyStepCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L352){target="_blank" style="float:right; font-size:smaller"}
#
# ### IgnoreLaggyStepCallback
#
# >      IgnoreLaggyStepCallback (timeout=0.1)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(MemoryFullRecoverCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L340){target="_blank" style="float:right; font-size:smaller"}
#
# ### MemoryFullRecoverCallback
#
# >      MemoryFullRecoverCallback (percent_threshold=90.0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(TelemetryTimeoutRecoverCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L328){target="_blank" style="float:right; font-size:smaller"}
#
# ### TelemetryTimeoutRecoverCallback
#
# >      TelemetryTimeoutRecoverCallback (timeout=10.0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(LagCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L375){target="_blank" style="float:right; font-size:smaller"}
#
# ### LagCallback
#
# >      LagCallback ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(StepPublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L425){target="_blank" style="float:right; font-size:smaller"}
#
# ### StepPublisherCallback
#
# >      StepPublisherCallback (publisher_queue)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ActionPublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L411){target="_blank" style="float:right; font-size:smaller"}
#
# ### ActionPublisherCallback
#
# >      ActionPublisherCallback (publisher_queue)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(PublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L400){target="_blank" style="float:right; font-size:smaller"}
#
# ### PublisherCallback
#
# >      PublisherCallback (publisher_queue)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(publish)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L393){target="_blank" style="float:right; font-size:smaller"}
#
# ### publish
#
# >      publish (queue, payload)

# %%
#| echo: false
#| output: asis
show_doc(EigenCamPublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L434){target="_blank" style="float:right; font-size:smaller"}
#
# ### EigenCamPublisherCallback
#
# >      EigenCamPublisherCallback (publisher_queue)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(SessionPublisherCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L519){target="_blank" style="float:right; font-size:smaller"}
#
# ### SessionPublisherCallback
#
# >      SessionPublisherCallback (publisher_queue)
#
# Require WandbCollectorCallback

# %%
#| echo: false
#| output: asis
show_doc(SessionStats)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/collector.py#L453){target="_blank" style="float:right; font-size:smaller"}
#
# ### SessionStats
