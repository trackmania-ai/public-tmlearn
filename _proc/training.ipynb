# %% [raw]
# ---
# description: Manager coordinating a training
# output-file: training.html
# title: Training
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Training)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L38){target="_blank" style="float:right; font-size:smaller"}
#
# ### Training
#
# >      Training (map_scheduler, envs, agent, replay_buffer, session_scheduler,
# >                collector_cbs=[], training_cbs=[], batch_size=32, burnin=1024,
# >                online=True, log_every=2, ws_port=2013,
# >                wandb_project='tmaifoo', wandb_entity='trackmania-ai',
# >                wandb_load_group=None, wandb_load_agent='agent-latest.pth')
#
# Initialize self.  See help(type(self)) for accurate signature.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | map_scheduler |  |  |  |
# | envs |  |  |  |
# | agent |  |  |  |
# | replay_buffer |  |  |  |
# | session_scheduler |  |  |  |
# | collector_cbs | list | [] |  |
# | training_cbs | list | [] |  |
# | batch_size | int | 32 |  |
# | burnin | int | 1024 |  |
# ...

# %%
#| echo: false
#| output: asis
show_doc(OneMapScheduler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L240){target="_blank" style="float:right; font-size:smaller"}
#
# ### OneMapScheduler
#
# >      OneMapScheduler (map_uid)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(MapScheduler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L204){target="_blank" style="float:right; font-size:smaller"}
#
# ### MapScheduler
#
# >      MapScheduler (maps_uid)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ExperienceTimeoutCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L262){target="_blank" style="float:right; font-size:smaller"}
#
# ### ExperienceTimeoutCallback
#
# >      ExperienceTimeoutCallback (timeout=300)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ExperienceTimeoutException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L258){target="_blank" style="float:right; font-size:smaller"}
#
# ### ExperienceTimeoutException
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(LrSchedulerCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L274){target="_blank" style="float:right; font-size:smaller"}
#
# ### LrSchedulerCallback
#
# >      LrSchedulerCallback (scheduler, max_time)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(WandbSaveAgentPersistentCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L314){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbSaveAgentPersistentCallback
#
# >      WandbSaveAgentPersistentCallback (every=172800)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(WandbSaveAgentSlidingCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L294){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbSaveAgentSlidingCallback
#
# >      WandbSaveAgentSlidingCallback (every=3600, nb_save=25)
#
# Initialize self.  See help(type(self)) for accurate signature.
