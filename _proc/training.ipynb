# %% [raw]
# ---
# description: Manager coordinating a training
# output-file: training.html
# title: Training
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Training)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L35){target="_blank" style="float:right; font-size:smaller"}
#
# ### Training
#
# >      Training (map_scheduler, envs, agent, replay_buffer, session_scheduler,
# >                collector_cbs=[], training_cbs=[], batch_size=32, burnin=1024,
# >                online=True, ws_port=2013, wandb_project='tmaifoo',
# >                wandb_entity='trackmania-ai', wandb_load_group=None,
# >                wandb_load_file='agent/agent-latest.pth')
#
# Initialize self.  See help(type(self)) for accurate signature.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | map_scheduler |  |  |  |
# | envs |  |  |  |
# | agent |  |  |  |
# | replay_buffer |  |  |  |
# | session_scheduler |  |  |  |
# | collector_cbs | list | [] |  |
# | training_cbs | list | [] |  |
# | batch_size | int | 32 |  |
# | burnin | int | 1024 |  |
# | online | bool | True | Activate websocket and wandb logging |
# | ws_port | int | 2013 |  |
# | wandb_project | str | tmaifoo |  |
# | wandb_entity | str | trackmania-ai |  |
# | wandb_load_group | NoneType | None |  |
# | wandb_load_file | str | agent/agent-latest.pth |  |

# %%
#| echo: false
#| output: asis
show_doc(MapScheduler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L194){target="_blank" style="float:right; font-size:smaller"}
#
# ### MapScheduler
#
# >      MapScheduler (maps_uid)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(LrSchedulerCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L232){target="_blank" style="float:right; font-size:smaller"}
#
# ### LrSchedulerCallback
#
# >      LrSchedulerCallback (scheduler, max_time)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(WandbSaveAgentPersistentCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L272){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbSaveAgentPersistentCallback
#
# >      WandbSaveAgentPersistentCallback (every=86400)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(WandbSaveAgentSlidingCallback)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/training.py#L252){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbSaveAgentSlidingCallback
#
# >      WandbSaveAgentSlidingCallback (every=3600, nb_save=13)
#
# Initialize self.  See help(type(self)) for accurate signature.
