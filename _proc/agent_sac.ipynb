# %% [raw]
# ---
# description: Agent allowing to pick an action and fit one batch for training using
#   SAC algorithm
# output-file: agent_sac.html
# title: SAC Agent
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(TwinnedCriticNet)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/agent/sac.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### TwinnedCriticNet
#
# >      TwinnedCriticNet (critic_model_fn)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
#     As per the example above, an ``__init__()`` call to the parent class
#     must be made before assignment on the child.
#
# :ivar training: Boolean represents whether this module is in training or
#                 evaluation mode.
# :vartype training: bool

# %%
#| echo: false
#| output: asis
show_doc(SacAgent)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/agent/sac.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### SacAgent
#
# >      SacAgent (actor_model, critic_model_fn, action_space, device='cpu',
# >                gamma=0.99, tau=0.005, optimizer_fn=functools.partial(<function
# >                Adam at 0x7fa12873c160>, lr=1e-05, wd=0.0001))
#
# Initialize self.  See help(type(self)) for accurate signature.
