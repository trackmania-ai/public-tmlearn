# %% [raw]
# ---
# description: Neural networks models used by the AI to learn
# output-file: neural.html
# title: Neural
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(DuelingNet)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L120){target="_blank" style="float:right; font-size:smaller"}
#
# ### DuelingNet
#
# >      DuelingNet (model, output_dim, hidden=256, p=0.0)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# ...

# %%
#| echo: false
#| output: asis
show_doc(Conv1dFlat)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L113){target="_blank" style="float:right; font-size:smaller"}
#
# ### Conv1dFlat
#
# >      Conv1dFlat (input_dim, hidden=16)
#
# A sequential container.
# Modules will be added to it in the order they are passed in the
# constructor. Alternatively, an ``OrderedDict`` of modules can be
# passed in. The ``forward()`` method of ``Sequential`` accepts any
# input and forwards it to the first module it contains. It then
# "chains" outputs to inputs sequentially for each subsequent module,
# finally returning the output of the last module.
#
# The value a ``Sequential`` provides over manually calling a sequence
# of modules is that it allows treating the whole container as a
# single module, such that performing a transformation on the
# ``Sequential`` applies to each of the modules it stores (which are
# each a registered submodule of the ``Sequential``).
#
# ...

# %%
#| echo: false
#| output: asis
show_doc(FlatLinearNet)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L103){target="_blank" style="float:right; font-size:smaller"}
#
# ### FlatLinearNet
#
# >      FlatLinearNet (input_dim, hidden=64, output_dim=32, p=0.0,
# >                     act=ReLU(inplace=True))
#
# A sequential container.
# Modules will be added to it in the order they are passed in the
# constructor. Alternatively, an ``OrderedDict`` of modules can be
# passed in. The ``forward()`` method of ``Sequential`` accepts any
# input and forwards it to the first module it contains. It then
# "chains" outputs to inputs sequentially for each subsequent module,
# finally returning the output of the last module.
#
# The value a ``Sequential`` provides over manually calling a sequence
# of modules is that it allows treating the whole container as a
# single module, such that performing a transformation on the
# ``Sequential`` applies to each of the modules it stores (which are
# ...

# %%
#| echo: false
#| output: asis
show_doc(VisualNet)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L89){target="_blank" style="float:right; font-size:smaller"}
#
# ### VisualNet
#
# >      VisualNet (model, input_dim, hidden=16)
#
# A sequential container.
# Modules will be added to it in the order they are passed in the
# constructor. Alternatively, an ``OrderedDict`` of modules can be
# passed in. The ``forward()`` method of ``Sequential`` accepts any
# input and forwards it to the first module it contains. It then
# "chains" outputs to inputs sequentially for each subsequent module,
# finally returning the output of the last module.
#
# The value a ``Sequential`` provides over manually calling a sequence
# of modules is that it allows treating the whole container as a
# single module, such that performing a transformation on the
# ``Sequential`` applies to each of the modules it stores (which are
# each a registered submodule of the ``Sequential``).
#
# ...

# %%
#| echo: false
#| output: asis
show_doc(TimmModel)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L60){target="_blank" style="float:right; font-size:smaller"}
#
# ### TimmModel
#
# >      TimmModel (name, input_dim, positional=False, pretrained=True,
# >                 global_pool='catavgmax')
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# ...

# %%
#| echo: false
#| output: asis
show_doc(truncated_timm_model)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L56){target="_blank" style="float:right; font-size:smaller"}
#
# ### truncated_timm_model
#
# >      truncated_timm_model (name, nb_trunc=1, pretrained=True)

# %%
#| echo: false
#| output: asis
show_doc(Flatten)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L50){target="_blank" style="float:right; font-size:smaller"}
#
# ### Flatten
#
# >      Flatten (input_dim)
#
# Flattens a contiguous range of dims into a tensor. For use with :class:`~nn.Sequential`.
#
# Shape:
#     - Input: :math:`(*, S_{\text{start}},..., S_{i}, ..., S_{\text{end}}, *)`,'
#       where :math:`S_{i}` is the size at dimension :math:`i` and :math:`*` means any
#       number of dimensions including none.
#     - Output: :math:`(*, \prod_{i=\text{start}}^{\text{end}} S_{i}, *)`.
#
# Args:
#     start_dim: first dim to flatten (default = 1).
#     end_dim: last dim to flatten (default = -1).
#
# Examples::
#     >>> input = torch.randn(32, 1, 5, 5)
#     >>> # With default parameters
#     >>> m = nn.Flatten()
#     >>> output = m(input)
#     >>> output.size()
#     torch.Size([32, 25])
#     >>> # With non-default parameters
#     >>> m = nn.Flatten(0, 2)
# ...

# %%
#| echo: false
#| output: asis
show_doc(StateCatNet)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### StateCatNet
#
# >      StateCatNet (**module_mapping)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
# ...

# %%
#| echo: false
#| output: asis
show_doc(init_weights)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/neural.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### init_weights
#
# >      init_weights (m)
