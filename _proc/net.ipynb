# %% [raw]
# ---
# description: Networking utilities
# output-file: net.html
# title: Net
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(ThreadServer)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/net.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### ThreadServer
#
# >      ThreadServer (app, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(WebsocketServer)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmlearn/tree/master/blob/master/tmlearn/net.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### WebsocketServer
#
# >      WebsocketServer (port)
#
# Initialize self.  See help(type(self)) for accurate signature.
